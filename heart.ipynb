# %% [markdown]
# <a href="https://colab.research.google.com/github/AatmajRakshe/Synapse_Tasks/blob/ML/heart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np

# %%
#import all the prerequisites like tensorflow and keras
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense,Activation,LeakyReLU
from sklearn.model_selection import train_test_split
import re
from keras.optimizers import SGD,Adam
import numpy as np
from numpy.random import seed
import tensorflow as tf
import random as rn
seed(100)
rn.seed(100)
tf.random.set_seed(100)

# %%
model=Sequential([
    Dense(64, input_shape=(13,)),
    LeakyReLU(alpha=0.1),
    Dense(32),
    LeakyReLU(alpha=0.1),
    Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(

# %%
df = pd.read_csv('/content/drive/MyDrive/DataSet/heart.csv')
df
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# 2        2   0     2       1
# 3        2   0     2       1
# 4        2   0     2       1
# ..     ...  ..   ...     ...
# 298      1   0     3       0
# 299      1   0     3       0
# 300      1   2     3       0
# 301      1   1     3       0
# 302      1   1     2       0
#
# [303 rows x 14 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Assuming 'df' is your DataFrame
columns_to_normalize = ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Normalize the specified columns
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])
df
# Out:
#           age  sex  cp  trestbps      chol  fbs  restecg   thalach  exang  \
# 0    0.708333    1   3  0.481132  0.244292    1        0  0.603053      0
# 1    0.166667    1   2  0.339623  0.283105    0        1  0.885496      0
# 2    0.250000    0   1  0.339623  0.178082    0        0  0.770992      0
# 3    0.562500    1   1  0.245283  0.251142    0        1  0.816794      0
# 4    0.583333    0   0  0.245283  0.520548    0        1  0.702290      1
# ..        ...  ...  ..       ...       ...  ...      ...       ...    ...
# 298  0.583333    0   0  0.433962  0.262557    0        1  0.396947      1
# 299  0.333333    1   3  0.150943  0.315068    0        1  0.465649      0
# 300  0.812500    1   0  0.471698  0.152968    1        1  0.534351      0
# 301  0.583333    1   0  0.339623  0.011416    0        1  0.335878      1
# 302  0.583333    0   1  0.339623  0.251142    0        0  0.786260      0
#
#       oldpeak  slope  ca  thal  target
# 0    0.370968      0   0     1       1
# 1    0.564516      0   0     2       1
# 2    0.225806      2   0     2       1
# 3    0.129032      2   0     2       1
# 4    0.096774      2   0     2       1
# ..        ...    ...  ..   ...     ...
# 298  0.032258      1   0     3       0
# 299  0.193548      1   0     3       0
# 300  0.548387      1   2     3       0
# 301  0.193548      1   1     3       0
# 302  0.000000      1   1     2       0
#
# [303 rows x 14 columns]

# %%
y = df['target']
X = df.drop('target',axis=1)
X_train,X_test,y_train,y_test = train_test_split(X ,y , test_size=0.3, random_state=42)
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (212, 13)
# (91, 13)
# (212,)
# (91,)

# %%
model.compile(optimizer=Adam(learning_rate=0.1), loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32,epochs=25)
# Out:
# Epoch 1/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.4808 - loss: 1.4275
# Epoch 2/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7978 - loss: 0.4990
# Epoch 3/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7339 - loss: 0.6302
# Epoch 4/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.7805 - loss: 0.4828
# Epoch 5/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8107 - loss: 0.4568
# Epoch 6/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8047 - loss: 0.4580
# Epoch 7/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8052 - loss: 0.3855
# Epoch 8/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8540 - loss: 0.3642
# Epoch 9/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8516 - loss: 0.3732
# Epoch 10/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8538 - loss: 0.3681
# Epoch 11/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8403 - loss: 0.3426
# Epoch 12/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8730 - loss: 0.3397
# Epoch 13/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8619 - loss: 0.3462
# Epoch 14/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8804 - loss: 0.3599
# Epoch 15/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8574 - loss: 0.3625
# Epoch 16/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.8821 - loss: 0.3049
# Epoch 17/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8660 - loss: 0.2991
# Epoch 18/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8503 - loss: 0.3213
# Epoch 19/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8422 - loss: 0.3722
# Epoch 20/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8576 - loss: 0.3809
# Epoch 21/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8771 - loss: 0.2928
# Epoch 22/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8795 - loss: 0.2807
# Epoch 23/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8674 - loss: 0.3316
# Epoch 24/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8572 - loss: 0.3952
# Epoch 25/25
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8363 - loss: 0.3315

# %%
y_pred = model.predict(X_test)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step

# %%
y_pred_classes = (y_pred > 0.5).astype(int)
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred_classes)
print(f"Accuracy: {accuracy*100}")
# Out:
# Accuracy: 85.71428571428571

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_11 (Dense)                     │ (None, 64)                  │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_8 (LeakyReLU)            │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)            │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 9,029 (35.27 KB)
#  Trainable params: 3,009 (11.75 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 6,020 (23.52 KB)

# %%
from sklearn.metrics import confusion_matrix

# Assuming y_test and y_pred_classes are defined from your previous code

conf_matrix = confusion_matrix(y_test, y_pred_classes)

print("Confusion Matrix:")
print(conf_matrix)

# You can also visualize the matrix (optional)
import matplotlib.pyplot as plt
import seaborn as sns

sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues",
            xticklabels=['Predicted 0', 'Predicted 1'],
            yticklabels=['Actual 0', 'Actual 1'])
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()
# Out:
# Confusion Matrix:
# [[35  6]
#  [ 7 43]]

# %%
model.save('/content/drive/MyDrive/heart_disease_model.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
